# %%
#Importing libraries
import numpy as np
import pandas as pd
import pandas_profiling as pf

#Required imports
import time, datetime

#Visualization imports
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.style.use('seaborn-whitegrid')

import warnings
warnings. filterwarnings('ignore')

# preprocessing
from sklearn.preprocessing import LabelEncoder

from statsmodels.tsa.stattools import adfuller, acf, pacf
from statsmodels.tsa.arima_model import ARIMA
#from statsmodels.tsa.statespace import SARIMAX
from statsmodels.tsa.seasonal import seasonal_decompose
from sklearn.metrics import mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-81442ab5c444> in <module>
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import pandas_profiling as pf
#       5
#       6 #Required imports
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
df_car_train = pd.read_csv('train_E1GspfA.csv', header=0)
df_car_train.head()

# %%
df_car_train.shape

# %%
df_car_train.info()

# %%
#Checking missing values
df_car_train.isnull().sum()

# %%
# No null values

# %%
#Get the Descriptive Stats about the Numeric data along with the categorical feature
df_car_train.describe(include='all')

# %%
# Finding Duplicate rows
duplicate_rows = df_car_train[df_car_train.duplicated(keep="first")]
duplicate_rows

# %%
#As datetime is an object time, coverting it into multiple columns
df_car_train['date'] = pd.to_datetime(df_car_train['date'])
df_car_train['date'] = df_car_train['date'].dt.date
df_car_train.head()

# %%
df_car_train.index = pd.to_datetime(df_car_train['date'])
df_car_train.drop(columns='date',inplace=True)
df_car_train.head()

# %%
# Visualizing Hour column
sns.countplot(df_car_train.hour)

# %%
# Visualizing date column
plt.figure(figsize=(16,6))
plt.tight_layout()
sns.countplot(df_car_train.date)

# %%
# Visualizing Demad column
sns.countplot(df_car_train.demand)

# %%
df_car_train.demand.plot()

# %%
#For Target variable
plt.figure(figsize=(12,6))
sns.distplot(df_car_train.demand)

# %%
# Outlier Analysis 
# As the maximum values is very much higher than the min, 0%, 25%, 50%, 75% of the data. This column will have outliers.
df_car_train.describe(include='all')

# %%
sns.boxplot(x=df_car_train.demand)

# %%
#Visualizing Hourly Car Demand
sns.scatterplot(x=df_car_train.hour, y=df_car_train.demand)

# %%
#Visualizing Quarterly Car Demand
plt.figure(figsize=(16,6))
plt.tight_layout()
sns.scatterplot(x=df_car_train.date, y=df_car_train.demand)

# %%
df_car_train.demand.value_counts()

# %%
'''#Visualizing patterns
plt.figure(figsize=(16,8))
sns.countplot(x='demand',data=df_car_train,hue='hour')'''

# %%
plt.figure(figsize=(16,8))
df_car_train.plot()

# %%
#Decomposing the time series
decompose_data = seasonal_decompose(df_car_train.demand, model="additive", period=4)
decompose_data.plot()

# %%
seasonality=decompose_data.seasonal
seasonality.plot(color='green')

# %%
trends=decompose_data.trend
plt.figure(figsize=(16,6))
trends.plot(color='green')

# %%
#For Target variable
sns.distplot(trends)

# %%
#For Target variable
plt.figure(figsize=(12,6))
sns.distplot(df_car_train.demand)
